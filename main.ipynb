# %%
import sys
sys.path.append('../../speechgrid/core')
from utils import load_speech_file

# %%
import os
from pathlib import Path

# %%
path_to_dataset = '../../../datasets/TAUKADIAL-24/'
train_dataset = os.path.join(path_to_dataset, 'train')
test_dataset = os.path.join(path_to_dataset, 'test')

# %%
train_wav_files = list(Path(train_dataset).rglob('*.wav'))

# %%
#Load the speech file
speech, sr, dur = load_speech_file(train_wav_files[100])

# %%
from IPython.display import Audio

# %%
Audio(data=speech, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
